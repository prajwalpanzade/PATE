# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwalpanzade/PATE/blob/main/PATE_medical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Deep Learning Model with Differntial Privacy
#
# If you have a private dataset and you want to train a deep learning model for some predictions, in most of cases you can't train model due to non-availabity of true labels. Let's take example, a hosptial has lots of unlabelled data for particular disease (like lung cancer). Even if other hospitals have labelled data, they can't share with others. In most of cases one hosptial doesn't have good number of labelled examples to train good model.
#
#
# ## Problem Assumption:-
#
# *   N Hospitals ( Teachers) have some labelled data with same kind of labels
# *   One Hosptial ( Student) have some unlabelled data
#
# ## Problem Solution :-
#
#
# *   Ask each of the N hospitals (Teachers) to train a model on their own datasets
# *   Use the N teachers models to predict on your local dataset, generating N labels for each datapoints
# *   Aggregate the N labels using a differential private (DP) query
# *   Train model with new aggregated labels on your own dataset
#
#
#
# Let's start by imports

# %%
# !pip install syft=="0.2.2a1"
# Out:
# Collecting syft==0.2.2a1
#   Downloading syft-0.2.2a1-py3-none-any.whl (337 kB)
#      |████████████████████████████████| 337 kB 23.3 MB/s
# Requirement already satisfied: msgpack>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.2a1) (1.0.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.2a1) (1.21.4)
# Requirement already satisfied: Flask>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.2a1) (1.1.4)
# Collecting Pillow<7
#   Downloading Pillow-6.2.2-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 42.3 MB/s
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.2a1) (1.4.1)
# Collecting torchvision==0.4.1
#   Downloading torchvision-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 48.8 MB/s
# Collecting torch==1.3
#   Downloading torch-1.3.0-cp37-cp37m-manylinux1_x86_64.whl (773.1 MB)
#      |████████████████████████████████| 773.1 MB 11 kB/s
# Collecting flask-socketio>=3.3.2
#   Downloading Flask_SocketIO-5.1.1-py3-none-any.whl (17 kB)
# Collecting syft-proto>=0.1.0a1.post23
#   Downloading syft_proto-0.5.3-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 4.5 MB/s
# Collecting websockets>=7.0
#   Downloading websockets-10.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (111 kB)
#      |████████████████████████████████| 111 kB 68.6 MB/s
# Collecting zstd>=1.4.0.0
#   Downloading zstd-1.5.1.0.tar.gz (604 kB)
#      |████████████████████████████████| 604 kB 61.8 MB/s
# Collecting lz4>=2.1.6
#   Downloading lz4-4.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 57.9 MB/s
# Requirement already satisfied: tblib>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from syft==0.2.2a1) (1.7.0)
# Collecting phe>=1.4.0
#   Downloading phe-1.4.0.tar.gz (35 kB)
# Collecting websocket-client>=0.56.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.1->syft==0.2.2a1) (1.15.0)
# Collecting Werkzeug<2.0,>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 55.5 MB/s
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->syft==0.2.2a1) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->syft==0.2.2a1) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.2->syft==0.2.2a1) (2.11.3)
# Collecting python-socketio>=5.0.2
#   Downloading python_socketio-5.5.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.2 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.2->syft==0.2.2a1) (2.0.1)
# Collecting python-engineio>=4.3.0
#   Downloading python_engineio-4.3.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Collecting bidict>=0.21.0
#   Downloading bidict-0.21.4-py3-none-any.whl (36 kB)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from syft-proto>=0.1.0a1.post23->syft==0.2.2a1) (3.19.1)
# Building wheels for collected packages: phe, zstd
#   Building wheel for phe (setup.py) ... done
#   Created wheel for phe: filename=phe-1.4.0-py2.py3-none-any.whl size=37362 sha256=6e70543553aa84305e1552544ac05aa7b5caba2f1dce633cd5978767fea26f00
#   Stored in directory: /root/.cache/pip/wheels/bb/ac/9b/b07a04fe6bb1418ab4ee06d6652757aef848b80363c4dac507
#   Building wheel for zstd (setup.py) ... done
#   Created wheel for zstd: filename=zstd-1.5.1.0-cp37-cp37m-linux_x86_64.whl size=1243865 sha256=7c55389383acc641e69f9142feae29eaf7ae533d4128ef0f24381abe94d5a1fe
#   Stored in directory: /root/.cache/pip/wheels/d3/6f/6b/5f6a226fe7f19031b533a9fc9545721d34cb4d11996a87ba14
# Successfully built phe zstd
# Installing collected packages: Werkzeug, python-engineio, bidict, torch, python-socketio, Pillow, zstd, websockets, websocket-client, torchvision, syft-proto, phe, lz4, flask-socketio, syft
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.2
#     Uninstalling Werkzeug-2.0.2:
#       Successfully uninstalled Werkzeug-2.0.2
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: syft
#     Found existing installation: syft 0.6.0
#     Uninstalling syft-0.6.0:
#       Successfully uninstalled syft-0.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.3.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.3.0 which is incompatible.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 6.2.2 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-6.2.2 Werkzeug-1.0.1 bidict-0.21.4 flask-socketio-5.1.1 lz4-4.0.0 phe-1.4.0 python-engineio-4.3.1 python-socketio-5.5.2 syft-0.2.2a1 syft-proto-0.5.3 torch-1.3.0 torchvision-0.4.1 websocket-client-1.3.1 websockets-10.2 zstd-1.5.1.0

# %%
import torch
import torchvision
import numpy as np
from torch import nn, optim
from torchvision import datasets, transforms

# %%
# use cuda if available
DEVICE = torch.device("cuda" if torch.cuda.is_available()
                      else "cpu")
print(f"Using {DEVICE} backend")

# number of teacher models.  
# our student model accuracy will depend on this parameter
num_teachers = 100 #@param {type:"integer"}
# Out:
# Using cuda backend

# %% [markdown]
# ## Teacher Models Training
#
# We will use MNIST data as dummy data to train Teachers and Student Models.
#
#
#
# *   MNIST Training Data will be divided in N( equal to number of teachers) subsets and each subset will train one teacher model.
# *   MNIST Test Data will be used as private or student data and will be assumed unlabelled.

# %%
# convert to tensor and normalize 
train_transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize([.5],[.5])])
# load training data
mnsit_dataset = datasets.MNIST('./mnsit', train=True, transform=train_transform, download=True, )
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnsit/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnsit/MNIST/raw/train-images-idx3-ubyte.gz to ./mnsit/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnsit/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnsit/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnsit/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnsit/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnsit/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnsit/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnsit/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnsit/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnsit/MNIST/raw

# %%
# divide mnist train data to num_teachers partitions
total_size = len(mnsit_dataset)
# length of each teacher dataset
lengths = [int(total_size/num_teachers)]*num_teachers
# list of all teacher dataset
teacher_datasets = torch.utils.data.random_split(mnsit_dataset, lengths)

# %%
# We will create basic model, which will be used for teacher and student training both
# It is not necessary to have same model structure for all teahders and even student model
class Network(nn.Module):
  def __init__(self):
    super(Network,self).__init__()
    # sequential layer : input size (batch_size, 28*28)
    self.layer = nn.Sequential(nn.Linear(28*28, 256),
                               # out size (batch_size, 256)
                               nn.BatchNorm1d(256),
                               # out size (batch_size, 256)
                               nn.ReLU(),
                               # out size (batch_size, 256)
                               nn.Dropout(0.5),
                               # out size (batch_size, 256)
                               nn.Linear(256, 64),
                               # out size (batch_size, 64)
                               nn.BatchNorm1d(64),
                               # out size (batch_size, 64)
                               nn.ReLU(),
                               # out size (batch_size, 64)
                               nn.Dropout(0.5),
                               # out size (batch_size, 64)
                               nn.Linear(64, 10),
                               # out size (batch_size, 10)
                               # we will use logsoftmax instead softmax
                               # softmax has expoential overflow issues
                               nn.LogSoftmax(dim=1)
                               # out size (batch_size, 10)
                              )

  def forward(self,x):
    # x size : (batch_size, 1, 28, 28)
    x = x.view(x.shape[0], -1)
    # x size : (batch_size, 784)
    x = self.layer(x)
    # x size : (batch_size, 10)
    return x

# %%
def train_model(dataset, checkpoint_file, num_epochs=10, do_validation=False):
  """ 
  Train a model for given dataset for given number of epochs and
  save last epoch model checkpoint
  
  Parameters: 
    dataset (torch.dataset): training data
    checkpoint_file (str): filename for saving model
    num_epochs (int): number of training epoch
    do_validation (bool): perform validation by dividing dataset in 90:10 ratio
          
  Returns: None
  
  """
  # if validation divide dataset to train and test set 90:10 ratio
  if do_validation:
    dataset_size = len(dataset)
    train_set, test_set = torch.utils.data.random_split(dataset, [int(0.9*dataset_size), int(0.1*dataset_size)])
    # create train and test dataloader
    trainloader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
    testloader = torch.utils.data.DataLoader(test_set, batch_size= 32, shuffle=True)
  else:
    # create train dataloader using full dataset
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)

  # create model and send to gpu
  model = Network().to(DEVICE)
  # we have used logsoftmax, so now NLLLoss
  criterion = nn.NLLLoss()
  # adam optimizer for training
  optimizer = optim.Adam(model.parameters(), lr=0.005)

  # train for num_epochs
  for epoch in range(num_epochs):
    # training accuracy and loss for logging
    train_accuracy = 0
    train_loss = 0
    # training dataloader
    for images, labels in trainloader:
      # zero accumlated grads
      optimizer.zero_grad()
      # send images, labels to gpu
      images, labels = images.to(DEVICE), labels.to(DEVICE)
      # run forward propagation
      output = model.forward(images)
      # calculate loss
      loss = criterion(output, labels)
      train_loss += loss.item()
      # calculate accuracy 
      top_out, top_class = output.topk(1, dim=1)
      success = (top_class==labels.view(*top_class.shape))
      train_accuracy += success.sum().item()
      # do backward propagation
      loss.backward()
      optimizer.step()
      
    if do_validation:
      # set model to evaluation
      model.eval()
      test_accuracy = 0
      test_loss = 0
      # do forward pass and calculate loss and accuracy 
      with torch.no_grad():
        for images, labels in testloader:
          images, labels = images.to(DEVICE), labels.to(DEVICE)
          output = model.forward(images)
          loss = criterion(output, labels)
          test_loss += loss.item()
          top_out, top_class = output.topk(1, dim=1) 
          success = (top_class==labels.view(*top_class.shape))
          test_accuracy += success.sum().item()
      # log train and test metrics
      print("Epoch: {}".format(epoch+1),
            "Train Loss: {:.3f}".format(train_loss/len(trainloader)),
            "Train Accuracy: {:.3f}".format(train_accuracy/len(train_set)),
            "Test Loss: {:.3f}".format(test_loss/len(testloader)),
            "Test Accuracy: {:.3f}".format(test_accuracy/len(test_set))
           )
      # set model to train
      model.train()
    else:
      # log only training metrics if no validation
      print("Epoch: {}".format(epoch+1),
            "Train Loss: {:.3f}".format(train_loss/len(trainloader)),
            "Train Accuracy: {:.3f}".format(train_accuracy/len(dataset))
           )
    # save trained teacher model
    torch.save(model.state_dict(), checkpoint_file)

# %%
# train all teachers models on MNIST partition datasets
for teacher in range(num_teachers):
  print("############################### Teacher {} Model Training #############################".format(teacher+1))
  train_model(teacher_datasets[teacher], f"checkpoint_teacher_{teacher+1}.pth")
# Out:
# ############################### Teacher 1 Model Training #############################
# Epoch: 1 Train Loss: 1.682 Train Accuracy: 0.470
# Epoch: 2 Train Loss: 1.033 Train Accuracy: 0.713
# Epoch: 3 Train Loss: 0.701 Train Accuracy: 0.805
# Epoch: 4 Train Loss: 0.570 Train Accuracy: 0.835
# Epoch: 5 Train Loss: 0.441 Train Accuracy: 0.880
# Epoch: 6 Train Loss: 0.357 Train Accuracy: 0.890
# Epoch: 7 Train Loss: 0.330 Train Accuracy: 0.902
# Epoch: 8 Train Loss: 0.356 Train Accuracy: 0.883
# Epoch: 9 Train Loss: 0.361 Train Accuracy: 0.878
# Epoch: 10 Train Loss: 0.344 Train Accuracy: 0.895
# ############################### Teacher 2 Model Training #############################
# Epoch: 1 Train Loss: 1.641 Train Accuracy: 0.482
# Epoch: 2 Train Loss: 0.962 Train Accuracy: 0.733
# Epoch: 3 Train Loss: 0.700 Train Accuracy: 0.802
# Epoch: 4 Train Loss: 0.527 Train Accuracy: 0.853
# Epoch: 5 Train Loss: 0.455 Train Accuracy: 0.878
# Epoch: 6 Train Loss: 0.389 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.325 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.302 Train Accuracy: 0.915
# Epoch: 9 Train Loss: 0.277 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.226 Train Accuracy: 0.942
# ############################### Teacher 3 Model Training #############################
# Epoch: 1 Train Loss: 1.731 Train Accuracy: 0.462
# Epoch: 2 Train Loss: 1.045 Train Accuracy: 0.717
# Epoch: 3 Train Loss: 0.774 Train Accuracy: 0.782
# Epoch: 4 Train Loss: 0.620 Train Accuracy: 0.818
# Epoch: 5 Train Loss: 0.459 Train Accuracy: 0.885
# Epoch: 6 Train Loss: 0.430 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.391 Train Accuracy: 0.875
# Epoch: 8 Train Loss: 0.361 Train Accuracy: 0.882
# Epoch: 9 Train Loss: 0.291 Train Accuracy: 0.908
# Epoch: 10 Train Loss: 0.252 Train Accuracy: 0.917
# ############################### Teacher 4 Model Training #############################
# Epoch: 1 Train Loss: 1.709 Train Accuracy: 0.445
# Epoch: 2 Train Loss: 1.067 Train Accuracy: 0.692
# Epoch: 3 Train Loss: 0.740 Train Accuracy: 0.808
# Epoch: 4 Train Loss: 0.597 Train Accuracy: 0.827
# Epoch: 5 Train Loss: 0.531 Train Accuracy: 0.840
# Epoch: 6 Train Loss: 0.423 Train Accuracy: 0.895
# Epoch: 7 Train Loss: 0.409 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.399 Train Accuracy: 0.882
# Epoch: 9 Train Loss: 0.290 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.242 Train Accuracy: 0.940
# ############################### Teacher 5 Model Training #############################
# Epoch: 1 Train Loss: 1.622 Train Accuracy: 0.523
# Epoch: 2 Train Loss: 0.982 Train Accuracy: 0.757
# Epoch: 3 Train Loss: 0.648 Train Accuracy: 0.822
# Epoch: 4 Train Loss: 0.557 Train Accuracy: 0.832
# Epoch: 5 Train Loss: 0.448 Train Accuracy: 0.878
# Epoch: 6 Train Loss: 0.423 Train Accuracy: 0.882
# Epoch: 7 Train Loss: 0.324 Train Accuracy: 0.912
# Epoch: 8 Train Loss: 0.304 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.349 Train Accuracy: 0.897
# Epoch: 10 Train Loss: 0.279 Train Accuracy: 0.925
# ############################### Teacher 6 Model Training #############################
# Epoch: 1 Train Loss: 1.718 Train Accuracy: 0.437
# Epoch: 2 Train Loss: 1.056 Train Accuracy: 0.717
# Epoch: 3 Train Loss: 0.718 Train Accuracy: 0.825
# Epoch: 4 Train Loss: 0.567 Train Accuracy: 0.838
# Epoch: 5 Train Loss: 0.452 Train Accuracy: 0.857
# Epoch: 6 Train Loss: 0.451 Train Accuracy: 0.860
# Epoch: 7 Train Loss: 0.314 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.339 Train Accuracy: 0.890
# Epoch: 9 Train Loss: 0.268 Train Accuracy: 0.932
# Epoch: 10 Train Loss: 0.275 Train Accuracy: 0.928
# ############################### Teacher 7 Model Training #############################
# Epoch: 1 Train Loss: 1.609 Train Accuracy: 0.493
# Epoch: 2 Train Loss: 0.969 Train Accuracy: 0.735
# Epoch: 3 Train Loss: 0.631 Train Accuracy: 0.843
# Epoch: 4 Train Loss: 0.564 Train Accuracy: 0.848
# Epoch: 5 Train Loss: 0.485 Train Accuracy: 0.860
# Epoch: 6 Train Loss: 0.423 Train Accuracy: 0.887
# Epoch: 7 Train Loss: 0.325 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.302 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.293 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.274 Train Accuracy: 0.912
# ############################### Teacher 8 Model Training #############################
# Epoch: 1 Train Loss: 1.709 Train Accuracy: 0.438
# Epoch: 2 Train Loss: 1.045 Train Accuracy: 0.717
# Epoch: 3 Train Loss: 0.741 Train Accuracy: 0.805
# Epoch: 4 Train Loss: 0.565 Train Accuracy: 0.857
# Epoch: 5 Train Loss: 0.476 Train Accuracy: 0.850
# Epoch: 6 Train Loss: 0.426 Train Accuracy: 0.885
# Epoch: 7 Train Loss: 0.374 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.332 Train Accuracy: 0.907
# Epoch: 9 Train Loss: 0.287 Train Accuracy: 0.913
# Epoch: 10 Train Loss: 0.246 Train Accuracy: 0.925
# ############################### Teacher 9 Model Training #############################
# Epoch: 1 Train Loss: 1.703 Train Accuracy: 0.472
# Epoch: 2 Train Loss: 1.038 Train Accuracy: 0.728
# Epoch: 3 Train Loss: 0.729 Train Accuracy: 0.798
# Epoch: 4 Train Loss: 0.570 Train Accuracy: 0.833
# Epoch: 5 Train Loss: 0.470 Train Accuracy: 0.872
# Epoch: 6 Train Loss: 0.412 Train Accuracy: 0.885
# Epoch: 7 Train Loss: 0.344 Train Accuracy: 0.903
# Epoch: 8 Train Loss: 0.261 Train Accuracy: 0.935
# Epoch: 9 Train Loss: 0.301 Train Accuracy: 0.897
# Epoch: 10 Train Loss: 0.241 Train Accuracy: 0.932
# ############################### Teacher 10 Model Training #############################
# Epoch: 1 Train Loss: 1.642 Train Accuracy: 0.492
# Epoch: 2 Train Loss: 0.944 Train Accuracy: 0.760
# Epoch: 3 Train Loss: 0.637 Train Accuracy: 0.822
# Epoch: 4 Train Loss: 0.528 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.451 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.379 Train Accuracy: 0.882
# Epoch: 7 Train Loss: 0.359 Train Accuracy: 0.875
# Epoch: 8 Train Loss: 0.313 Train Accuracy: 0.895
# Epoch: 9 Train Loss: 0.233 Train Accuracy: 0.933
# Epoch: 10 Train Loss: 0.288 Train Accuracy: 0.900
# ############################### Teacher 11 Model Training #############################
# Epoch: 1 Train Loss: 1.672 Train Accuracy: 0.482
# Epoch: 2 Train Loss: 1.024 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.745 Train Accuracy: 0.815
# Epoch: 4 Train Loss: 0.537 Train Accuracy: 0.852
# Epoch: 5 Train Loss: 0.446 Train Accuracy: 0.888
# Epoch: 6 Train Loss: 0.374 Train Accuracy: 0.892
# Epoch: 7 Train Loss: 0.359 Train Accuracy: 0.885
# Epoch: 8 Train Loss: 0.332 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.289 Train Accuracy: 0.915
# Epoch: 10 Train Loss: 0.327 Train Accuracy: 0.903
# ############################### Teacher 12 Model Training #############################
# Epoch: 1 Train Loss: 1.650 Train Accuracy: 0.492
# Epoch: 2 Train Loss: 1.012 Train Accuracy: 0.747
# Epoch: 3 Train Loss: 0.690 Train Accuracy: 0.818
# Epoch: 4 Train Loss: 0.549 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.504 Train Accuracy: 0.860
# Epoch: 6 Train Loss: 0.417 Train Accuracy: 0.877
# Epoch: 7 Train Loss: 0.375 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.309 Train Accuracy: 0.910
# Epoch: 9 Train Loss: 0.317 Train Accuracy: 0.890
# Epoch: 10 Train Loss: 0.274 Train Accuracy: 0.915
# ############################### Teacher 13 Model Training #############################
# Epoch: 1 Train Loss: 1.641 Train Accuracy: 0.487
# Epoch: 2 Train Loss: 0.969 Train Accuracy: 0.733
# Epoch: 3 Train Loss: 0.695 Train Accuracy: 0.798
# Epoch: 4 Train Loss: 0.557 Train Accuracy: 0.833
# Epoch: 5 Train Loss: 0.447 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.407 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.336 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.267 Train Accuracy: 0.915
# Epoch: 9 Train Loss: 0.292 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.276 Train Accuracy: 0.910
# ############################### Teacher 14 Model Training #############################
# Epoch: 1 Train Loss: 1.684 Train Accuracy: 0.473
# Epoch: 2 Train Loss: 1.018 Train Accuracy: 0.717
# Epoch: 3 Train Loss: 0.715 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.572 Train Accuracy: 0.847
# Epoch: 5 Train Loss: 0.477 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.443 Train Accuracy: 0.870
# Epoch: 7 Train Loss: 0.400 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.357 Train Accuracy: 0.885
# Epoch: 9 Train Loss: 0.369 Train Accuracy: 0.887
# Epoch: 10 Train Loss: 0.275 Train Accuracy: 0.922
# ############################### Teacher 15 Model Training #############################
# Epoch: 1 Train Loss: 1.701 Train Accuracy: 0.445
# Epoch: 2 Train Loss: 1.084 Train Accuracy: 0.732
# Epoch: 3 Train Loss: 0.769 Train Accuracy: 0.783
# Epoch: 4 Train Loss: 0.630 Train Accuracy: 0.827
# Epoch: 5 Train Loss: 0.551 Train Accuracy: 0.825
# Epoch: 6 Train Loss: 0.476 Train Accuracy: 0.850
# Epoch: 7 Train Loss: 0.422 Train Accuracy: 0.878
# Epoch: 8 Train Loss: 0.390 Train Accuracy: 0.870
# Epoch: 9 Train Loss: 0.380 Train Accuracy: 0.872
# Epoch: 10 Train Loss: 0.355 Train Accuracy: 0.892
# ############################### Teacher 16 Model Training #############################
# Epoch: 1 Train Loss: 1.614 Train Accuracy: 0.495
# Epoch: 2 Train Loss: 1.012 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.693 Train Accuracy: 0.808
# Epoch: 4 Train Loss: 0.544 Train Accuracy: 0.840
# Epoch: 5 Train Loss: 0.463 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.426 Train Accuracy: 0.865
# Epoch: 7 Train Loss: 0.365 Train Accuracy: 0.903
# Epoch: 8 Train Loss: 0.327 Train Accuracy: 0.902
# Epoch: 9 Train Loss: 0.288 Train Accuracy: 0.908
# Epoch: 10 Train Loss: 0.219 Train Accuracy: 0.935
# ############################### Teacher 17 Model Training #############################
# Epoch: 1 Train Loss: 1.810 Train Accuracy: 0.438
# Epoch: 2 Train Loss: 1.082 Train Accuracy: 0.700
# Epoch: 3 Train Loss: 0.771 Train Accuracy: 0.770
# Epoch: 4 Train Loss: 0.649 Train Accuracy: 0.805
# Epoch: 5 Train Loss: 0.534 Train Accuracy: 0.840
# Epoch: 6 Train Loss: 0.451 Train Accuracy: 0.868
# Epoch: 7 Train Loss: 0.358 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.307 Train Accuracy: 0.902
# Epoch: 9 Train Loss: 0.323 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.293 Train Accuracy: 0.918
# ############################### Teacher 18 Model Training #############################
# Epoch: 1 Train Loss: 1.647 Train Accuracy: 0.480
# Epoch: 2 Train Loss: 0.977 Train Accuracy: 0.755
# Epoch: 3 Train Loss: 0.645 Train Accuracy: 0.832
# Epoch: 4 Train Loss: 0.485 Train Accuracy: 0.878
# Epoch: 5 Train Loss: 0.401 Train Accuracy: 0.888
# Epoch: 6 Train Loss: 0.378 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.356 Train Accuracy: 0.890
# Epoch: 8 Train Loss: 0.312 Train Accuracy: 0.910
# Epoch: 9 Train Loss: 0.324 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.282 Train Accuracy: 0.910
# ############################### Teacher 19 Model Training #############################
# Epoch: 1 Train Loss: 1.681 Train Accuracy: 0.477
# Epoch: 2 Train Loss: 0.941 Train Accuracy: 0.745
# Epoch: 3 Train Loss: 0.676 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.577 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.492 Train Accuracy: 0.857
# Epoch: 6 Train Loss: 0.426 Train Accuracy: 0.875
# Epoch: 7 Train Loss: 0.392 Train Accuracy: 0.865
# Epoch: 8 Train Loss: 0.315 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.301 Train Accuracy: 0.900
# Epoch: 10 Train Loss: 0.295 Train Accuracy: 0.907
# ############################### Teacher 20 Model Training #############################
# Epoch: 1 Train Loss: 1.688 Train Accuracy: 0.470
# Epoch: 2 Train Loss: 1.057 Train Accuracy: 0.703
# Epoch: 3 Train Loss: 0.736 Train Accuracy: 0.802
# Epoch: 4 Train Loss: 0.546 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.492 Train Accuracy: 0.858
# Epoch: 6 Train Loss: 0.393 Train Accuracy: 0.870
# Epoch: 7 Train Loss: 0.398 Train Accuracy: 0.865
# Epoch: 8 Train Loss: 0.347 Train Accuracy: 0.888
# Epoch: 9 Train Loss: 0.345 Train Accuracy: 0.890
# Epoch: 10 Train Loss: 0.320 Train Accuracy: 0.897
# ############################### Teacher 21 Model Training #############################
# Epoch: 1 Train Loss: 1.652 Train Accuracy: 0.478
# Epoch: 2 Train Loss: 0.989 Train Accuracy: 0.750
# Epoch: 3 Train Loss: 0.660 Train Accuracy: 0.825
# Epoch: 4 Train Loss: 0.549 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.456 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.410 Train Accuracy: 0.868
# Epoch: 7 Train Loss: 0.375 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.362 Train Accuracy: 0.893
# Epoch: 9 Train Loss: 0.267 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.251 Train Accuracy: 0.918
# ############################### Teacher 22 Model Training #############################
# Epoch: 1 Train Loss: 1.629 Train Accuracy: 0.480
# Epoch: 2 Train Loss: 1.013 Train Accuracy: 0.713
# Epoch: 3 Train Loss: 0.699 Train Accuracy: 0.798
# Epoch: 4 Train Loss: 0.545 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.461 Train Accuracy: 0.867
# Epoch: 6 Train Loss: 0.360 Train Accuracy: 0.892
# Epoch: 7 Train Loss: 0.361 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.331 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.282 Train Accuracy: 0.920
# Epoch: 10 Train Loss: 0.281 Train Accuracy: 0.910
# ############################### Teacher 23 Model Training #############################
# Epoch: 1 Train Loss: 1.625 Train Accuracy: 0.490
# Epoch: 2 Train Loss: 0.936 Train Accuracy: 0.732
# Epoch: 3 Train Loss: 0.665 Train Accuracy: 0.802
# Epoch: 4 Train Loss: 0.558 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.468 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.400 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.349 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.326 Train Accuracy: 0.897
# Epoch: 9 Train Loss: 0.279 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.254 Train Accuracy: 0.915
# ############################### Teacher 24 Model Training #############################
# Epoch: 1 Train Loss: 1.596 Train Accuracy: 0.517
# Epoch: 2 Train Loss: 0.960 Train Accuracy: 0.743
# Epoch: 3 Train Loss: 0.685 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.509 Train Accuracy: 0.880
# Epoch: 5 Train Loss: 0.384 Train Accuracy: 0.905
# Epoch: 6 Train Loss: 0.383 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.306 Train Accuracy: 0.907
# Epoch: 8 Train Loss: 0.296 Train Accuracy: 0.915
# Epoch: 9 Train Loss: 0.261 Train Accuracy: 0.920
# Epoch: 10 Train Loss: 0.238 Train Accuracy: 0.917
# ############################### Teacher 25 Model Training #############################
# Epoch: 1 Train Loss: 1.686 Train Accuracy: 0.435
# Epoch: 2 Train Loss: 0.977 Train Accuracy: 0.737
# Epoch: 3 Train Loss: 0.746 Train Accuracy: 0.783
# Epoch: 4 Train Loss: 0.508 Train Accuracy: 0.887
# Epoch: 5 Train Loss: 0.434 Train Accuracy: 0.880
# Epoch: 6 Train Loss: 0.423 Train Accuracy: 0.865
# Epoch: 7 Train Loss: 0.396 Train Accuracy: 0.878
# Epoch: 8 Train Loss: 0.331 Train Accuracy: 0.910
# Epoch: 9 Train Loss: 0.272 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.265 Train Accuracy: 0.910
# ############################### Teacher 26 Model Training #############################
# Epoch: 1 Train Loss: 1.657 Train Accuracy: 0.475
# Epoch: 2 Train Loss: 0.985 Train Accuracy: 0.725
# Epoch: 3 Train Loss: 0.674 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.556 Train Accuracy: 0.857
# Epoch: 5 Train Loss: 0.463 Train Accuracy: 0.855
# Epoch: 6 Train Loss: 0.384 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.383 Train Accuracy: 0.890
# Epoch: 8 Train Loss: 0.386 Train Accuracy: 0.883
# Epoch: 9 Train Loss: 0.270 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.297 Train Accuracy: 0.903
# ############################### Teacher 27 Model Training #############################
# Epoch: 1 Train Loss: 1.683 Train Accuracy: 0.472
# Epoch: 2 Train Loss: 1.074 Train Accuracy: 0.707
# Epoch: 3 Train Loss: 0.739 Train Accuracy: 0.808
# Epoch: 4 Train Loss: 0.590 Train Accuracy: 0.822
# Epoch: 5 Train Loss: 0.492 Train Accuracy: 0.852
# Epoch: 6 Train Loss: 0.417 Train Accuracy: 0.870
# Epoch: 7 Train Loss: 0.380 Train Accuracy: 0.870
# Epoch: 8 Train Loss: 0.381 Train Accuracy: 0.877
# Epoch: 9 Train Loss: 0.308 Train Accuracy: 0.920
# Epoch: 10 Train Loss: 0.307 Train Accuracy: 0.900
# ############################### Teacher 28 Model Training #############################
# Epoch: 1 Train Loss: 1.677 Train Accuracy: 0.462
# Epoch: 2 Train Loss: 1.014 Train Accuracy: 0.737
# Epoch: 3 Train Loss: 0.732 Train Accuracy: 0.808
# Epoch: 4 Train Loss: 0.551 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.433 Train Accuracy: 0.877
# Epoch: 6 Train Loss: 0.388 Train Accuracy: 0.897
# Epoch: 7 Train Loss: 0.368 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.327 Train Accuracy: 0.907
# Epoch: 9 Train Loss: 0.294 Train Accuracy: 0.915
# Epoch: 10 Train Loss: 0.281 Train Accuracy: 0.928
# ############################### Teacher 29 Model Training #############################
# Epoch: 1 Train Loss: 1.668 Train Accuracy: 0.488
# Epoch: 2 Train Loss: 1.010 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.739 Train Accuracy: 0.805
# Epoch: 4 Train Loss: 0.604 Train Accuracy: 0.827
# Epoch: 5 Train Loss: 0.479 Train Accuracy: 0.868
# Epoch: 6 Train Loss: 0.412 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.381 Train Accuracy: 0.883
# Epoch: 8 Train Loss: 0.327 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.273 Train Accuracy: 0.930
# Epoch: 10 Train Loss: 0.264 Train Accuracy: 0.922
# ############################### Teacher 30 Model Training #############################
# Epoch: 1 Train Loss: 1.669 Train Accuracy: 0.467
# Epoch: 2 Train Loss: 1.022 Train Accuracy: 0.698
# Epoch: 3 Train Loss: 0.753 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.558 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.443 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.417 Train Accuracy: 0.882
# Epoch: 7 Train Loss: 0.382 Train Accuracy: 0.872
# Epoch: 8 Train Loss: 0.309 Train Accuracy: 0.897
# Epoch: 9 Train Loss: 0.267 Train Accuracy: 0.923
# Epoch: 10 Train Loss: 0.269 Train Accuracy: 0.928
# ############################### Teacher 31 Model Training #############################
# Epoch: 1 Train Loss: 1.711 Train Accuracy: 0.452
# Epoch: 2 Train Loss: 1.033 Train Accuracy: 0.723
# Epoch: 3 Train Loss: 0.701 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.565 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.439 Train Accuracy: 0.883
# Epoch: 6 Train Loss: 0.412 Train Accuracy: 0.893
# Epoch: 7 Train Loss: 0.380 Train Accuracy: 0.885
# Epoch: 8 Train Loss: 0.315 Train Accuracy: 0.895
# Epoch: 9 Train Loss: 0.290 Train Accuracy: 0.923
# Epoch: 10 Train Loss: 0.279 Train Accuracy: 0.908
# ############################### Teacher 32 Model Training #############################
# Epoch: 1 Train Loss: 1.740 Train Accuracy: 0.418
# Epoch: 2 Train Loss: 1.092 Train Accuracy: 0.682
# Epoch: 3 Train Loss: 0.758 Train Accuracy: 0.768
# Epoch: 4 Train Loss: 0.605 Train Accuracy: 0.840
# Epoch: 5 Train Loss: 0.483 Train Accuracy: 0.853
# Epoch: 6 Train Loss: 0.468 Train Accuracy: 0.847
# Epoch: 7 Train Loss: 0.394 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.386 Train Accuracy: 0.890
# Epoch: 9 Train Loss: 0.353 Train Accuracy: 0.895
# Epoch: 10 Train Loss: 0.292 Train Accuracy: 0.913
# ############################### Teacher 33 Model Training #############################
# Epoch: 1 Train Loss: 1.607 Train Accuracy: 0.510
# Epoch: 2 Train Loss: 0.984 Train Accuracy: 0.723
# Epoch: 3 Train Loss: 0.682 Train Accuracy: 0.828
# Epoch: 4 Train Loss: 0.550 Train Accuracy: 0.843
# Epoch: 5 Train Loss: 0.468 Train Accuracy: 0.877
# Epoch: 6 Train Loss: 0.349 Train Accuracy: 0.897
# Epoch: 7 Train Loss: 0.352 Train Accuracy: 0.902
# Epoch: 8 Train Loss: 0.292 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.298 Train Accuracy: 0.920
# Epoch: 10 Train Loss: 0.314 Train Accuracy: 0.910
# ############################### Teacher 34 Model Training #############################
# Epoch: 1 Train Loss: 1.609 Train Accuracy: 0.493
# Epoch: 2 Train Loss: 0.966 Train Accuracy: 0.733
# Epoch: 3 Train Loss: 0.712 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.507 Train Accuracy: 0.852
# Epoch: 5 Train Loss: 0.507 Train Accuracy: 0.855
# Epoch: 6 Train Loss: 0.459 Train Accuracy: 0.867
# Epoch: 7 Train Loss: 0.362 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.411 Train Accuracy: 0.878
# Epoch: 9 Train Loss: 0.312 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.315 Train Accuracy: 0.903
# ############################### Teacher 35 Model Training #############################
# Epoch: 1 Train Loss: 1.656 Train Accuracy: 0.482
# Epoch: 2 Train Loss: 1.005 Train Accuracy: 0.728
# Epoch: 3 Train Loss: 0.711 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.546 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.466 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.429 Train Accuracy: 0.867
# Epoch: 7 Train Loss: 0.335 Train Accuracy: 0.895
# Epoch: 8 Train Loss: 0.322 Train Accuracy: 0.903
# Epoch: 9 Train Loss: 0.317 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.267 Train Accuracy: 0.922
# ############################### Teacher 36 Model Training #############################
# Epoch: 1 Train Loss: 1.636 Train Accuracy: 0.503
# Epoch: 2 Train Loss: 0.952 Train Accuracy: 0.775
# Epoch: 3 Train Loss: 0.624 Train Accuracy: 0.843
# Epoch: 4 Train Loss: 0.477 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.387 Train Accuracy: 0.883
# Epoch: 6 Train Loss: 0.335 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.281 Train Accuracy: 0.923
# Epoch: 8 Train Loss: 0.332 Train Accuracy: 0.887
# Epoch: 9 Train Loss: 0.262 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.209 Train Accuracy: 0.937
# ############################### Teacher 37 Model Training #############################
# Epoch: 1 Train Loss: 1.681 Train Accuracy: 0.463
# Epoch: 2 Train Loss: 0.992 Train Accuracy: 0.747
# Epoch: 3 Train Loss: 0.678 Train Accuracy: 0.812
# Epoch: 4 Train Loss: 0.585 Train Accuracy: 0.822
# Epoch: 5 Train Loss: 0.502 Train Accuracy: 0.860
# Epoch: 6 Train Loss: 0.393 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.357 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.330 Train Accuracy: 0.897
# Epoch: 9 Train Loss: 0.335 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.247 Train Accuracy: 0.925
# ############################### Teacher 38 Model Training #############################
# Epoch: 1 Train Loss: 1.678 Train Accuracy: 0.500
# Epoch: 2 Train Loss: 1.055 Train Accuracy: 0.682
# Epoch: 3 Train Loss: 0.734 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.521 Train Accuracy: 0.848
# Epoch: 5 Train Loss: 0.466 Train Accuracy: 0.858
# Epoch: 6 Train Loss: 0.343 Train Accuracy: 0.905
# Epoch: 7 Train Loss: 0.309 Train Accuracy: 0.923
# Epoch: 8 Train Loss: 0.350 Train Accuracy: 0.902
# Epoch: 9 Train Loss: 0.313 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.288 Train Accuracy: 0.910
# ############################### Teacher 39 Model Training #############################
# Epoch: 1 Train Loss: 1.685 Train Accuracy: 0.465
# Epoch: 2 Train Loss: 1.000 Train Accuracy: 0.723
# Epoch: 3 Train Loss: 0.766 Train Accuracy: 0.772
# Epoch: 4 Train Loss: 0.570 Train Accuracy: 0.843
# Epoch: 5 Train Loss: 0.446 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.412 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.382 Train Accuracy: 0.885
# Epoch: 8 Train Loss: 0.336 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.312 Train Accuracy: 0.898
# Epoch: 10 Train Loss: 0.274 Train Accuracy: 0.918
# ############################### Teacher 40 Model Training #############################
# Epoch: 1 Train Loss: 1.627 Train Accuracy: 0.485
# Epoch: 2 Train Loss: 1.018 Train Accuracy: 0.713
# Epoch: 3 Train Loss: 0.730 Train Accuracy: 0.802
# Epoch: 4 Train Loss: 0.542 Train Accuracy: 0.852
# Epoch: 5 Train Loss: 0.435 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.405 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.353 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.337 Train Accuracy: 0.890
# Epoch: 9 Train Loss: 0.276 Train Accuracy: 0.925
# Epoch: 10 Train Loss: 0.216 Train Accuracy: 0.942
# ############################### Teacher 41 Model Training #############################
# Epoch: 1 Train Loss: 1.617 Train Accuracy: 0.497
# Epoch: 2 Train Loss: 0.992 Train Accuracy: 0.740
# Epoch: 3 Train Loss: 0.669 Train Accuracy: 0.815
# Epoch: 4 Train Loss: 0.544 Train Accuracy: 0.833
# Epoch: 5 Train Loss: 0.509 Train Accuracy: 0.842
# Epoch: 6 Train Loss: 0.360 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.327 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.334 Train Accuracy: 0.900
# Epoch: 9 Train Loss: 0.276 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.290 Train Accuracy: 0.907
# ############################### Teacher 42 Model Training #############################
# Epoch: 1 Train Loss: 1.692 Train Accuracy: 0.487
# Epoch: 2 Train Loss: 0.945 Train Accuracy: 0.750
# Epoch: 3 Train Loss: 0.730 Train Accuracy: 0.792
# Epoch: 4 Train Loss: 0.576 Train Accuracy: 0.837
# Epoch: 5 Train Loss: 0.464 Train Accuracy: 0.850
# Epoch: 6 Train Loss: 0.368 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.361 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.318 Train Accuracy: 0.885
# Epoch: 9 Train Loss: 0.250 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.278 Train Accuracy: 0.917
# ############################### Teacher 43 Model Training #############################
# Epoch: 1 Train Loss: 1.595 Train Accuracy: 0.518
# Epoch: 2 Train Loss: 0.951 Train Accuracy: 0.755
# Epoch: 3 Train Loss: 0.686 Train Accuracy: 0.818
# Epoch: 4 Train Loss: 0.556 Train Accuracy: 0.837
# Epoch: 5 Train Loss: 0.463 Train Accuracy: 0.867
# Epoch: 6 Train Loss: 0.387 Train Accuracy: 0.897
# Epoch: 7 Train Loss: 0.308 Train Accuracy: 0.912
# Epoch: 8 Train Loss: 0.293 Train Accuracy: 0.918
# Epoch: 9 Train Loss: 0.266 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.241 Train Accuracy: 0.940
# ############################### Teacher 44 Model Training #############################
# Epoch: 1 Train Loss: 1.640 Train Accuracy: 0.505
# Epoch: 2 Train Loss: 0.965 Train Accuracy: 0.742
# Epoch: 3 Train Loss: 0.743 Train Accuracy: 0.783
# Epoch: 4 Train Loss: 0.503 Train Accuracy: 0.870
# Epoch: 5 Train Loss: 0.458 Train Accuracy: 0.877
# Epoch: 6 Train Loss: 0.444 Train Accuracy: 0.877
# Epoch: 7 Train Loss: 0.352 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.334 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.300 Train Accuracy: 0.908
# Epoch: 10 Train Loss: 0.302 Train Accuracy: 0.912
# ############################### Teacher 45 Model Training #############################
# Epoch: 1 Train Loss: 1.681 Train Accuracy: 0.462
# Epoch: 2 Train Loss: 1.078 Train Accuracy: 0.682
# Epoch: 3 Train Loss: 0.786 Train Accuracy: 0.773
# Epoch: 4 Train Loss: 0.544 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.460 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.420 Train Accuracy: 0.863
# Epoch: 7 Train Loss: 0.372 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.314 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.296 Train Accuracy: 0.903
# Epoch: 10 Train Loss: 0.266 Train Accuracy: 0.917
# ############################### Teacher 46 Model Training #############################
# Epoch: 1 Train Loss: 1.694 Train Accuracy: 0.467
# Epoch: 2 Train Loss: 1.006 Train Accuracy: 0.743
# Epoch: 3 Train Loss: 0.741 Train Accuracy: 0.793
# Epoch: 4 Train Loss: 0.592 Train Accuracy: 0.850
# Epoch: 5 Train Loss: 0.471 Train Accuracy: 0.868
# Epoch: 6 Train Loss: 0.364 Train Accuracy: 0.908
# Epoch: 7 Train Loss: 0.353 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.386 Train Accuracy: 0.880
# Epoch: 9 Train Loss: 0.296 Train Accuracy: 0.920
# Epoch: 10 Train Loss: 0.251 Train Accuracy: 0.935
# ############################### Teacher 47 Model Training #############################
# Epoch: 1 Train Loss: 1.677 Train Accuracy: 0.478
# Epoch: 2 Train Loss: 1.072 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.708 Train Accuracy: 0.795
# Epoch: 4 Train Loss: 0.518 Train Accuracy: 0.847
# Epoch: 5 Train Loss: 0.448 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.359 Train Accuracy: 0.913
# Epoch: 7 Train Loss: 0.406 Train Accuracy: 0.880
# Epoch: 8 Train Loss: 0.289 Train Accuracy: 0.927
# Epoch: 9 Train Loss: 0.280 Train Accuracy: 0.932
# Epoch: 10 Train Loss: 0.269 Train Accuracy: 0.935
# ############################### Teacher 48 Model Training #############################
# Epoch: 1 Train Loss: 1.697 Train Accuracy: 0.467
# Epoch: 2 Train Loss: 1.022 Train Accuracy: 0.732
# Epoch: 3 Train Loss: 0.702 Train Accuracy: 0.818
# Epoch: 4 Train Loss: 0.562 Train Accuracy: 0.832
# Epoch: 5 Train Loss: 0.468 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.393 Train Accuracy: 0.895
# Epoch: 7 Train Loss: 0.322 Train Accuracy: 0.913
# Epoch: 8 Train Loss: 0.302 Train Accuracy: 0.922
# Epoch: 9 Train Loss: 0.256 Train Accuracy: 0.937
# Epoch: 10 Train Loss: 0.288 Train Accuracy: 0.917
# ############################### Teacher 49 Model Training #############################
# Epoch: 1 Train Loss: 1.641 Train Accuracy: 0.468
# Epoch: 2 Train Loss: 0.962 Train Accuracy: 0.738
# Epoch: 3 Train Loss: 0.661 Train Accuracy: 0.828
# Epoch: 4 Train Loss: 0.525 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.456 Train Accuracy: 0.857
# Epoch: 6 Train Loss: 0.382 Train Accuracy: 0.897
# Epoch: 7 Train Loss: 0.339 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.309 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.285 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.255 Train Accuracy: 0.933
# ############################### Teacher 50 Model Training #############################
# Epoch: 1 Train Loss: 1.607 Train Accuracy: 0.520
# Epoch: 2 Train Loss: 0.918 Train Accuracy: 0.760
# Epoch: 3 Train Loss: 0.671 Train Accuracy: 0.815
# Epoch: 4 Train Loss: 0.536 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.420 Train Accuracy: 0.893
# Epoch: 6 Train Loss: 0.351 Train Accuracy: 0.903
# Epoch: 7 Train Loss: 0.329 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.265 Train Accuracy: 0.922
# Epoch: 9 Train Loss: 0.263 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.218 Train Accuracy: 0.932
# ############################### Teacher 51 Model Training #############################
# Epoch: 1 Train Loss: 1.713 Train Accuracy: 0.450
# Epoch: 2 Train Loss: 1.016 Train Accuracy: 0.743
# Epoch: 3 Train Loss: 0.704 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.510 Train Accuracy: 0.865
# Epoch: 5 Train Loss: 0.417 Train Accuracy: 0.898
# Epoch: 6 Train Loss: 0.370 Train Accuracy: 0.882
# Epoch: 7 Train Loss: 0.338 Train Accuracy: 0.902
# Epoch: 8 Train Loss: 0.307 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.291 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.265 Train Accuracy: 0.927
# ############################### Teacher 52 Model Training #############################
# Epoch: 1 Train Loss: 1.721 Train Accuracy: 0.458
# Epoch: 2 Train Loss: 1.101 Train Accuracy: 0.698
# Epoch: 3 Train Loss: 0.751 Train Accuracy: 0.783
# Epoch: 4 Train Loss: 0.562 Train Accuracy: 0.852
# Epoch: 5 Train Loss: 0.479 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.433 Train Accuracy: 0.867
# Epoch: 7 Train Loss: 0.382 Train Accuracy: 0.878
# Epoch: 8 Train Loss: 0.374 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.322 Train Accuracy: 0.897
# Epoch: 10 Train Loss: 0.335 Train Accuracy: 0.902
# ############################### Teacher 53 Model Training #############################
# Epoch: 1 Train Loss: 1.666 Train Accuracy: 0.487
# Epoch: 2 Train Loss: 0.997 Train Accuracy: 0.750
# Epoch: 3 Train Loss: 0.753 Train Accuracy: 0.797
# Epoch: 4 Train Loss: 0.545 Train Accuracy: 0.865
# Epoch: 5 Train Loss: 0.481 Train Accuracy: 0.858
# Epoch: 6 Train Loss: 0.414 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.416 Train Accuracy: 0.875
# Epoch: 8 Train Loss: 0.377 Train Accuracy: 0.878
# Epoch: 9 Train Loss: 0.295 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.300 Train Accuracy: 0.912
# ############################### Teacher 54 Model Training #############################
# Epoch: 1 Train Loss: 1.689 Train Accuracy: 0.465
# Epoch: 2 Train Loss: 1.062 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.740 Train Accuracy: 0.785
# Epoch: 4 Train Loss: 0.586 Train Accuracy: 0.833
# Epoch: 5 Train Loss: 0.478 Train Accuracy: 0.868
# Epoch: 6 Train Loss: 0.430 Train Accuracy: 0.863
# Epoch: 7 Train Loss: 0.359 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.329 Train Accuracy: 0.888
# Epoch: 9 Train Loss: 0.308 Train Accuracy: 0.905
# Epoch: 10 Train Loss: 0.303 Train Accuracy: 0.923
# ############################### Teacher 55 Model Training #############################
# Epoch: 1 Train Loss: 1.639 Train Accuracy: 0.470
# Epoch: 2 Train Loss: 0.983 Train Accuracy: 0.740
# Epoch: 3 Train Loss: 0.676 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.554 Train Accuracy: 0.830
# Epoch: 5 Train Loss: 0.459 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.389 Train Accuracy: 0.890
# Epoch: 7 Train Loss: 0.330 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.306 Train Accuracy: 0.918
# Epoch: 9 Train Loss: 0.263 Train Accuracy: 0.937
# Epoch: 10 Train Loss: 0.243 Train Accuracy: 0.932
# ############################### Teacher 56 Model Training #############################
# Epoch: 1 Train Loss: 1.738 Train Accuracy: 0.452
# Epoch: 2 Train Loss: 1.016 Train Accuracy: 0.727
# Epoch: 3 Train Loss: 0.776 Train Accuracy: 0.772
# Epoch: 4 Train Loss: 0.559 Train Accuracy: 0.857
# Epoch: 5 Train Loss: 0.488 Train Accuracy: 0.882
# Epoch: 6 Train Loss: 0.409 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.378 Train Accuracy: 0.868
# Epoch: 8 Train Loss: 0.345 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.311 Train Accuracy: 0.893
# Epoch: 10 Train Loss: 0.277 Train Accuracy: 0.913
# ############################### Teacher 57 Model Training #############################
# Epoch: 1 Train Loss: 1.686 Train Accuracy: 0.478
# Epoch: 2 Train Loss: 1.006 Train Accuracy: 0.705
# Epoch: 3 Train Loss: 0.718 Train Accuracy: 0.780
# Epoch: 4 Train Loss: 0.533 Train Accuracy: 0.848
# Epoch: 5 Train Loss: 0.479 Train Accuracy: 0.848
# Epoch: 6 Train Loss: 0.498 Train Accuracy: 0.833
# Epoch: 7 Train Loss: 0.433 Train Accuracy: 0.860
# Epoch: 8 Train Loss: 0.343 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.342 Train Accuracy: 0.897
# Epoch: 10 Train Loss: 0.288 Train Accuracy: 0.907
# ############################### Teacher 58 Model Training #############################
# Epoch: 1 Train Loss: 1.601 Train Accuracy: 0.520
# Epoch: 2 Train Loss: 0.935 Train Accuracy: 0.757
# Epoch: 3 Train Loss: 0.691 Train Accuracy: 0.812
# Epoch: 4 Train Loss: 0.510 Train Accuracy: 0.865
# Epoch: 5 Train Loss: 0.399 Train Accuracy: 0.902
# Epoch: 6 Train Loss: 0.354 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.365 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.342 Train Accuracy: 0.890
# Epoch: 9 Train Loss: 0.306 Train Accuracy: 0.907
# Epoch: 10 Train Loss: 0.282 Train Accuracy: 0.910
# ############################### Teacher 59 Model Training #############################
# Epoch: 1 Train Loss: 1.693 Train Accuracy: 0.472
# Epoch: 2 Train Loss: 0.975 Train Accuracy: 0.755
# Epoch: 3 Train Loss: 0.669 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.528 Train Accuracy: 0.860
# Epoch: 5 Train Loss: 0.444 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.367 Train Accuracy: 0.905
# Epoch: 7 Train Loss: 0.401 Train Accuracy: 0.867
# Epoch: 8 Train Loss: 0.312 Train Accuracy: 0.903
# Epoch: 9 Train Loss: 0.266 Train Accuracy: 0.928
# Epoch: 10 Train Loss: 0.271 Train Accuracy: 0.917
# ############################### Teacher 60 Model Training #############################
# Epoch: 1 Train Loss: 1.688 Train Accuracy: 0.458
# Epoch: 2 Train Loss: 0.994 Train Accuracy: 0.775
# Epoch: 3 Train Loss: 0.746 Train Accuracy: 0.797
# Epoch: 4 Train Loss: 0.562 Train Accuracy: 0.832
# Epoch: 5 Train Loss: 0.430 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.401 Train Accuracy: 0.885
# Epoch: 7 Train Loss: 0.313 Train Accuracy: 0.913
# Epoch: 8 Train Loss: 0.310 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.279 Train Accuracy: 0.913
# Epoch: 10 Train Loss: 0.264 Train Accuracy: 0.927
# ############################### Teacher 61 Model Training #############################
# Epoch: 1 Train Loss: 1.658 Train Accuracy: 0.490
# Epoch: 2 Train Loss: 0.992 Train Accuracy: 0.738
# Epoch: 3 Train Loss: 0.686 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.533 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.467 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.432 Train Accuracy: 0.863
# Epoch: 7 Train Loss: 0.359 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.356 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.252 Train Accuracy: 0.928
# Epoch: 10 Train Loss: 0.263 Train Accuracy: 0.925
# ############################### Teacher 62 Model Training #############################
# Epoch: 1 Train Loss: 1.682 Train Accuracy: 0.453
# Epoch: 2 Train Loss: 1.014 Train Accuracy: 0.737
# Epoch: 3 Train Loss: 0.710 Train Accuracy: 0.802
# Epoch: 4 Train Loss: 0.528 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.466 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.410 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.367 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.297 Train Accuracy: 0.913
# Epoch: 9 Train Loss: 0.295 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.297 Train Accuracy: 0.915
# ############################### Teacher 63 Model Training #############################
# Epoch: 1 Train Loss: 1.709 Train Accuracy: 0.460
# Epoch: 2 Train Loss: 1.039 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.754 Train Accuracy: 0.783
# Epoch: 4 Train Loss: 0.563 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.489 Train Accuracy: 0.855
# Epoch: 6 Train Loss: 0.439 Train Accuracy: 0.868
# Epoch: 7 Train Loss: 0.384 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.372 Train Accuracy: 0.878
# Epoch: 9 Train Loss: 0.317 Train Accuracy: 0.902
# Epoch: 10 Train Loss: 0.257 Train Accuracy: 0.922
# ############################### Teacher 64 Model Training #############################
# Epoch: 1 Train Loss: 1.644 Train Accuracy: 0.492
# Epoch: 2 Train Loss: 0.970 Train Accuracy: 0.750
# Epoch: 3 Train Loss: 0.679 Train Accuracy: 0.793
# Epoch: 4 Train Loss: 0.567 Train Accuracy: 0.840
# Epoch: 5 Train Loss: 0.478 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.369 Train Accuracy: 0.905
# Epoch: 7 Train Loss: 0.357 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.275 Train Accuracy: 0.928
# Epoch: 9 Train Loss: 0.289 Train Accuracy: 0.927
# Epoch: 10 Train Loss: 0.258 Train Accuracy: 0.918
# ############################### Teacher 65 Model Training #############################
# Epoch: 1 Train Loss: 1.657 Train Accuracy: 0.500
# Epoch: 2 Train Loss: 1.033 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.706 Train Accuracy: 0.815
# Epoch: 4 Train Loss: 0.507 Train Accuracy: 0.853
# Epoch: 5 Train Loss: 0.365 Train Accuracy: 0.907
# Epoch: 6 Train Loss: 0.397 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.317 Train Accuracy: 0.888
# Epoch: 8 Train Loss: 0.265 Train Accuracy: 0.933
# Epoch: 9 Train Loss: 0.295 Train Accuracy: 0.893
# Epoch: 10 Train Loss: 0.281 Train Accuracy: 0.918
# ############################### Teacher 66 Model Training #############################
# Epoch: 1 Train Loss: 1.659 Train Accuracy: 0.465
# Epoch: 2 Train Loss: 1.032 Train Accuracy: 0.697
# Epoch: 3 Train Loss: 0.740 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.561 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.464 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.403 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.342 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.300 Train Accuracy: 0.917
# Epoch: 9 Train Loss: 0.316 Train Accuracy: 0.895
# Epoch: 10 Train Loss: 0.260 Train Accuracy: 0.913
# ############################### Teacher 67 Model Training #############################
# Epoch: 1 Train Loss: 1.647 Train Accuracy: 0.488
# Epoch: 2 Train Loss: 1.044 Train Accuracy: 0.708
# Epoch: 3 Train Loss: 0.788 Train Accuracy: 0.782
# Epoch: 4 Train Loss: 0.632 Train Accuracy: 0.812
# Epoch: 5 Train Loss: 0.522 Train Accuracy: 0.862
# Epoch: 6 Train Loss: 0.464 Train Accuracy: 0.860
# Epoch: 7 Train Loss: 0.360 Train Accuracy: 0.908
# Epoch: 8 Train Loss: 0.347 Train Accuracy: 0.895
# Epoch: 9 Train Loss: 0.305 Train Accuracy: 0.908
# Epoch: 10 Train Loss: 0.306 Train Accuracy: 0.902
# ############################### Teacher 68 Model Training #############################
# Epoch: 1 Train Loss: 1.594 Train Accuracy: 0.480
# Epoch: 2 Train Loss: 0.993 Train Accuracy: 0.730
# Epoch: 3 Train Loss: 0.707 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.595 Train Accuracy: 0.832
# Epoch: 5 Train Loss: 0.467 Train Accuracy: 0.872
# Epoch: 6 Train Loss: 0.446 Train Accuracy: 0.870
# Epoch: 7 Train Loss: 0.399 Train Accuracy: 0.885
# Epoch: 8 Train Loss: 0.332 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.315 Train Accuracy: 0.898
# Epoch: 10 Train Loss: 0.272 Train Accuracy: 0.923
# ############################### Teacher 69 Model Training #############################
# Epoch: 1 Train Loss: 1.585 Train Accuracy: 0.497
# Epoch: 2 Train Loss: 0.993 Train Accuracy: 0.733
# Epoch: 3 Train Loss: 0.738 Train Accuracy: 0.790
# Epoch: 4 Train Loss: 0.580 Train Accuracy: 0.830
# Epoch: 5 Train Loss: 0.517 Train Accuracy: 0.855
# Epoch: 6 Train Loss: 0.416 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.371 Train Accuracy: 0.887
# Epoch: 8 Train Loss: 0.339 Train Accuracy: 0.903
# Epoch: 9 Train Loss: 0.297 Train Accuracy: 0.898
# Epoch: 10 Train Loss: 0.296 Train Accuracy: 0.910
# ############################### Teacher 70 Model Training #############################
# Epoch: 1 Train Loss: 1.615 Train Accuracy: 0.483
# Epoch: 2 Train Loss: 0.986 Train Accuracy: 0.740
# Epoch: 3 Train Loss: 0.703 Train Accuracy: 0.812
# Epoch: 4 Train Loss: 0.551 Train Accuracy: 0.852
# Epoch: 5 Train Loss: 0.461 Train Accuracy: 0.868
# Epoch: 6 Train Loss: 0.413 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.342 Train Accuracy: 0.903
# Epoch: 8 Train Loss: 0.314 Train Accuracy: 0.902
# Epoch: 9 Train Loss: 0.276 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.266 Train Accuracy: 0.917
# ############################### Teacher 71 Model Training #############################
# Epoch: 1 Train Loss: 1.634 Train Accuracy: 0.487
# Epoch: 2 Train Loss: 0.974 Train Accuracy: 0.742
# Epoch: 3 Train Loss: 0.710 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.586 Train Accuracy: 0.822
# Epoch: 5 Train Loss: 0.439 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.419 Train Accuracy: 0.887
# Epoch: 7 Train Loss: 0.363 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.337 Train Accuracy: 0.910
# Epoch: 9 Train Loss: 0.289 Train Accuracy: 0.895
# Epoch: 10 Train Loss: 0.273 Train Accuracy: 0.913
# ############################### Teacher 72 Model Training #############################
# Epoch: 1 Train Loss: 1.620 Train Accuracy: 0.523
# Epoch: 2 Train Loss: 0.956 Train Accuracy: 0.730
# Epoch: 3 Train Loss: 0.690 Train Accuracy: 0.820
# Epoch: 4 Train Loss: 0.508 Train Accuracy: 0.858
# Epoch: 5 Train Loss: 0.418 Train Accuracy: 0.873
# Epoch: 6 Train Loss: 0.345 Train Accuracy: 0.900
# Epoch: 7 Train Loss: 0.359 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.326 Train Accuracy: 0.892
# Epoch: 9 Train Loss: 0.348 Train Accuracy: 0.892
# Epoch: 10 Train Loss: 0.304 Train Accuracy: 0.907
# ############################### Teacher 73 Model Training #############################
# Epoch: 1 Train Loss: 1.681 Train Accuracy: 0.482
# Epoch: 2 Train Loss: 0.994 Train Accuracy: 0.733
# Epoch: 3 Train Loss: 0.675 Train Accuracy: 0.832
# Epoch: 4 Train Loss: 0.535 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.461 Train Accuracy: 0.863
# Epoch: 6 Train Loss: 0.385 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.369 Train Accuracy: 0.887
# Epoch: 8 Train Loss: 0.328 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.276 Train Accuracy: 0.922
# Epoch: 10 Train Loss: 0.287 Train Accuracy: 0.912
# ############################### Teacher 74 Model Training #############################
# Epoch: 1 Train Loss: 1.626 Train Accuracy: 0.502
# Epoch: 2 Train Loss: 0.927 Train Accuracy: 0.757
# Epoch: 3 Train Loss: 0.650 Train Accuracy: 0.838
# Epoch: 4 Train Loss: 0.489 Train Accuracy: 0.853
# Epoch: 5 Train Loss: 0.448 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.395 Train Accuracy: 0.885
# Epoch: 7 Train Loss: 0.361 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.270 Train Accuracy: 0.932
# Epoch: 9 Train Loss: 0.235 Train Accuracy: 0.930
# Epoch: 10 Train Loss: 0.234 Train Accuracy: 0.945
# ############################### Teacher 75 Model Training #############################
# Epoch: 1 Train Loss: 1.792 Train Accuracy: 0.422
# Epoch: 2 Train Loss: 1.103 Train Accuracy: 0.710
# Epoch: 3 Train Loss: 0.775 Train Accuracy: 0.787
# Epoch: 4 Train Loss: 0.580 Train Accuracy: 0.835
# Epoch: 5 Train Loss: 0.495 Train Accuracy: 0.845
# Epoch: 6 Train Loss: 0.415 Train Accuracy: 0.875
# Epoch: 7 Train Loss: 0.372 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.312 Train Accuracy: 0.913
# Epoch: 9 Train Loss: 0.320 Train Accuracy: 0.908
# Epoch: 10 Train Loss: 0.352 Train Accuracy: 0.902
# ############################### Teacher 76 Model Training #############################
# Epoch: 1 Train Loss: 1.782 Train Accuracy: 0.433
# Epoch: 2 Train Loss: 1.081 Train Accuracy: 0.702
# Epoch: 3 Train Loss: 0.737 Train Accuracy: 0.818
# Epoch: 4 Train Loss: 0.526 Train Accuracy: 0.873
# Epoch: 5 Train Loss: 0.437 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.342 Train Accuracy: 0.913
# Epoch: 7 Train Loss: 0.326 Train Accuracy: 0.913
# Epoch: 8 Train Loss: 0.300 Train Accuracy: 0.918
# Epoch: 9 Train Loss: 0.258 Train Accuracy: 0.910
# Epoch: 10 Train Loss: 0.237 Train Accuracy: 0.932
# ############################### Teacher 77 Model Training #############################
# Epoch: 1 Train Loss: 1.627 Train Accuracy: 0.457
# Epoch: 2 Train Loss: 0.926 Train Accuracy: 0.758
# Epoch: 3 Train Loss: 0.630 Train Accuracy: 0.862
# Epoch: 4 Train Loss: 0.467 Train Accuracy: 0.888
# Epoch: 5 Train Loss: 0.396 Train Accuracy: 0.887
# Epoch: 6 Train Loss: 0.426 Train Accuracy: 0.870
# Epoch: 7 Train Loss: 0.330 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.302 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.260 Train Accuracy: 0.927
# Epoch: 10 Train Loss: 0.244 Train Accuracy: 0.930
# ############################### Teacher 78 Model Training #############################
# Epoch: 1 Train Loss: 1.603 Train Accuracy: 0.503
# Epoch: 2 Train Loss: 0.956 Train Accuracy: 0.723
# Epoch: 3 Train Loss: 0.660 Train Accuracy: 0.813
# Epoch: 4 Train Loss: 0.552 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.437 Train Accuracy: 0.888
# Epoch: 6 Train Loss: 0.369 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.331 Train Accuracy: 0.897
# Epoch: 8 Train Loss: 0.327 Train Accuracy: 0.912
# Epoch: 9 Train Loss: 0.288 Train Accuracy: 0.915
# Epoch: 10 Train Loss: 0.247 Train Accuracy: 0.930
# ############################### Teacher 79 Model Training #############################
# Epoch: 1 Train Loss: 1.597 Train Accuracy: 0.503
# Epoch: 2 Train Loss: 0.989 Train Accuracy: 0.740
# Epoch: 3 Train Loss: 0.682 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.535 Train Accuracy: 0.862
# Epoch: 5 Train Loss: 0.442 Train Accuracy: 0.880
# Epoch: 6 Train Loss: 0.399 Train Accuracy: 0.878
# Epoch: 7 Train Loss: 0.366 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.321 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.279 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.296 Train Accuracy: 0.897
# ############################### Teacher 80 Model Training #############################
# Epoch: 1 Train Loss: 1.664 Train Accuracy: 0.473
# Epoch: 2 Train Loss: 1.021 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.705 Train Accuracy: 0.798
# Epoch: 4 Train Loss: 0.559 Train Accuracy: 0.863
# Epoch: 5 Train Loss: 0.454 Train Accuracy: 0.875
# Epoch: 6 Train Loss: 0.450 Train Accuracy: 0.877
# Epoch: 7 Train Loss: 0.398 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.320 Train Accuracy: 0.902
# Epoch: 9 Train Loss: 0.257 Train Accuracy: 0.927
# Epoch: 10 Train Loss: 0.253 Train Accuracy: 0.918
# ############################### Teacher 81 Model Training #############################
# Epoch: 1 Train Loss: 1.732 Train Accuracy: 0.438
# Epoch: 2 Train Loss: 1.020 Train Accuracy: 0.725
# Epoch: 3 Train Loss: 0.743 Train Accuracy: 0.803
# Epoch: 4 Train Loss: 0.592 Train Accuracy: 0.843
# Epoch: 5 Train Loss: 0.450 Train Accuracy: 0.878
# Epoch: 6 Train Loss: 0.472 Train Accuracy: 0.858
# Epoch: 7 Train Loss: 0.396 Train Accuracy: 0.868
# Epoch: 8 Train Loss: 0.375 Train Accuracy: 0.875
# Epoch: 9 Train Loss: 0.340 Train Accuracy: 0.897
# Epoch: 10 Train Loss: 0.328 Train Accuracy: 0.905
# ############################### Teacher 82 Model Training #############################
# Epoch: 1 Train Loss: 1.647 Train Accuracy: 0.488
# Epoch: 2 Train Loss: 0.976 Train Accuracy: 0.752
# Epoch: 3 Train Loss: 0.709 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.550 Train Accuracy: 0.843
# Epoch: 5 Train Loss: 0.400 Train Accuracy: 0.892
# Epoch: 6 Train Loss: 0.342 Train Accuracy: 0.913
# Epoch: 7 Train Loss: 0.335 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.320 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.303 Train Accuracy: 0.905
# Epoch: 10 Train Loss: 0.271 Train Accuracy: 0.917
# ############################### Teacher 83 Model Training #############################
# Epoch: 1 Train Loss: 1.614 Train Accuracy: 0.490
# Epoch: 2 Train Loss: 0.926 Train Accuracy: 0.772
# Epoch: 3 Train Loss: 0.654 Train Accuracy: 0.828
# Epoch: 4 Train Loss: 0.483 Train Accuracy: 0.870
# Epoch: 5 Train Loss: 0.405 Train Accuracy: 0.885
# Epoch: 6 Train Loss: 0.364 Train Accuracy: 0.898
# Epoch: 7 Train Loss: 0.286 Train Accuracy: 0.918
# Epoch: 8 Train Loss: 0.271 Train Accuracy: 0.923
# Epoch: 9 Train Loss: 0.254 Train Accuracy: 0.932
# Epoch: 10 Train Loss: 0.228 Train Accuracy: 0.930
# ############################### Teacher 84 Model Training #############################
# Epoch: 1 Train Loss: 1.749 Train Accuracy: 0.412
# Epoch: 2 Train Loss: 1.025 Train Accuracy: 0.735
# Epoch: 3 Train Loss: 0.731 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.587 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.516 Train Accuracy: 0.848
# Epoch: 6 Train Loss: 0.378 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.411 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.297 Train Accuracy: 0.912
# Epoch: 9 Train Loss: 0.333 Train Accuracy: 0.888
# Epoch: 10 Train Loss: 0.269 Train Accuracy: 0.920
# ############################### Teacher 85 Model Training #############################
# Epoch: 1 Train Loss: 1.619 Train Accuracy: 0.502
# Epoch: 2 Train Loss: 0.892 Train Accuracy: 0.782
# Epoch: 3 Train Loss: 0.654 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.520 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.408 Train Accuracy: 0.885
# Epoch: 6 Train Loss: 0.352 Train Accuracy: 0.903
# Epoch: 7 Train Loss: 0.345 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.339 Train Accuracy: 0.900
# Epoch: 9 Train Loss: 0.309 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.241 Train Accuracy: 0.935
# ############################### Teacher 86 Model Training #############################
# Epoch: 1 Train Loss: 1.662 Train Accuracy: 0.463
# Epoch: 2 Train Loss: 0.969 Train Accuracy: 0.738
# Epoch: 3 Train Loss: 0.692 Train Accuracy: 0.833
# Epoch: 4 Train Loss: 0.549 Train Accuracy: 0.840
# Epoch: 5 Train Loss: 0.439 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.403 Train Accuracy: 0.895
# Epoch: 7 Train Loss: 0.370 Train Accuracy: 0.890
# Epoch: 8 Train Loss: 0.321 Train Accuracy: 0.910
# Epoch: 9 Train Loss: 0.304 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.234 Train Accuracy: 0.942
# ############################### Teacher 87 Model Training #############################
# Epoch: 1 Train Loss: 1.676 Train Accuracy: 0.460
# Epoch: 2 Train Loss: 0.967 Train Accuracy: 0.748
# Epoch: 3 Train Loss: 0.719 Train Accuracy: 0.797
# Epoch: 4 Train Loss: 0.560 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.450 Train Accuracy: 0.887
# Epoch: 6 Train Loss: 0.383 Train Accuracy: 0.893
# Epoch: 7 Train Loss: 0.365 Train Accuracy: 0.887
# Epoch: 8 Train Loss: 0.273 Train Accuracy: 0.925
# Epoch: 9 Train Loss: 0.276 Train Accuracy: 0.917
# Epoch: 10 Train Loss: 0.246 Train Accuracy: 0.933
# ############################### Teacher 88 Model Training #############################
# Epoch: 1 Train Loss: 1.743 Train Accuracy: 0.435
# Epoch: 2 Train Loss: 1.064 Train Accuracy: 0.715
# Epoch: 3 Train Loss: 0.699 Train Accuracy: 0.813
# Epoch: 4 Train Loss: 0.583 Train Accuracy: 0.830
# Epoch: 5 Train Loss: 0.421 Train Accuracy: 0.887
# Epoch: 6 Train Loss: 0.388 Train Accuracy: 0.882
# Epoch: 7 Train Loss: 0.351 Train Accuracy: 0.912
# Epoch: 8 Train Loss: 0.326 Train Accuracy: 0.913
# Epoch: 9 Train Loss: 0.303 Train Accuracy: 0.893
# Epoch: 10 Train Loss: 0.312 Train Accuracy: 0.903
# ############################### Teacher 89 Model Training #############################
# Epoch: 1 Train Loss: 1.671 Train Accuracy: 0.472
# Epoch: 2 Train Loss: 1.010 Train Accuracy: 0.707
# Epoch: 3 Train Loss: 0.713 Train Accuracy: 0.792
# Epoch: 4 Train Loss: 0.557 Train Accuracy: 0.845
# Epoch: 5 Train Loss: 0.436 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.380 Train Accuracy: 0.888
# Epoch: 7 Train Loss: 0.347 Train Accuracy: 0.892
# Epoch: 8 Train Loss: 0.301 Train Accuracy: 0.915
# Epoch: 9 Train Loss: 0.288 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.308 Train Accuracy: 0.908
# ############################### Teacher 90 Model Training #############################
# Epoch: 1 Train Loss: 1.697 Train Accuracy: 0.457
# Epoch: 2 Train Loss: 1.027 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.735 Train Accuracy: 0.792
# Epoch: 4 Train Loss: 0.579 Train Accuracy: 0.842
# Epoch: 5 Train Loss: 0.526 Train Accuracy: 0.823
# Epoch: 6 Train Loss: 0.418 Train Accuracy: 0.892
# Epoch: 7 Train Loss: 0.382 Train Accuracy: 0.877
# Epoch: 8 Train Loss: 0.372 Train Accuracy: 0.887
# Epoch: 9 Train Loss: 0.387 Train Accuracy: 0.885
# Epoch: 10 Train Loss: 0.284 Train Accuracy: 0.928
# ############################### Teacher 91 Model Training #############################
# Epoch: 1 Train Loss: 1.595 Train Accuracy: 0.518
# Epoch: 2 Train Loss: 0.950 Train Accuracy: 0.747
# Epoch: 3 Train Loss: 0.655 Train Accuracy: 0.833
# Epoch: 4 Train Loss: 0.477 Train Accuracy: 0.867
# Epoch: 5 Train Loss: 0.412 Train Accuracy: 0.890
# Epoch: 6 Train Loss: 0.329 Train Accuracy: 0.895
# Epoch: 7 Train Loss: 0.302 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.257 Train Accuracy: 0.928
# Epoch: 9 Train Loss: 0.292 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.216 Train Accuracy: 0.927
# ############################### Teacher 92 Model Training #############################
# Epoch: 1 Train Loss: 1.683 Train Accuracy: 0.467
# Epoch: 2 Train Loss: 0.994 Train Accuracy: 0.758
# Epoch: 3 Train Loss: 0.683 Train Accuracy: 0.835
# Epoch: 4 Train Loss: 0.521 Train Accuracy: 0.870
# Epoch: 5 Train Loss: 0.500 Train Accuracy: 0.847
# Epoch: 6 Train Loss: 0.397 Train Accuracy: 0.877
# Epoch: 7 Train Loss: 0.320 Train Accuracy: 0.918
# Epoch: 8 Train Loss: 0.319 Train Accuracy: 0.908
# Epoch: 9 Train Loss: 0.332 Train Accuracy: 0.892
# Epoch: 10 Train Loss: 0.243 Train Accuracy: 0.930
# ############################### Teacher 93 Model Training #############################
# Epoch: 1 Train Loss: 1.636 Train Accuracy: 0.478
# Epoch: 2 Train Loss: 0.975 Train Accuracy: 0.712
# Epoch: 3 Train Loss: 0.674 Train Accuracy: 0.817
# Epoch: 4 Train Loss: 0.470 Train Accuracy: 0.875
# Epoch: 5 Train Loss: 0.447 Train Accuracy: 0.867
# Epoch: 6 Train Loss: 0.358 Train Accuracy: 0.902
# Epoch: 7 Train Loss: 0.327 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.329 Train Accuracy: 0.897
# Epoch: 9 Train Loss: 0.316 Train Accuracy: 0.892
# Epoch: 10 Train Loss: 0.258 Train Accuracy: 0.917
# ############################### Teacher 94 Model Training #############################
# Epoch: 1 Train Loss: 1.669 Train Accuracy: 0.470
# Epoch: 2 Train Loss: 1.067 Train Accuracy: 0.692
# Epoch: 3 Train Loss: 0.705 Train Accuracy: 0.800
# Epoch: 4 Train Loss: 0.556 Train Accuracy: 0.848
# Epoch: 5 Train Loss: 0.516 Train Accuracy: 0.862
# Epoch: 6 Train Loss: 0.451 Train Accuracy: 0.873
# Epoch: 7 Train Loss: 0.342 Train Accuracy: 0.910
# Epoch: 8 Train Loss: 0.336 Train Accuracy: 0.898
# Epoch: 9 Train Loss: 0.281 Train Accuracy: 0.918
# Epoch: 10 Train Loss: 0.261 Train Accuracy: 0.923
# ############################### Teacher 95 Model Training #############################
# Epoch: 1 Train Loss: 1.695 Train Accuracy: 0.488
# Epoch: 2 Train Loss: 1.052 Train Accuracy: 0.725
# Epoch: 3 Train Loss: 0.714 Train Accuracy: 0.810
# Epoch: 4 Train Loss: 0.527 Train Accuracy: 0.862
# Epoch: 5 Train Loss: 0.419 Train Accuracy: 0.902
# Epoch: 6 Train Loss: 0.393 Train Accuracy: 0.893
# Epoch: 7 Train Loss: 0.353 Train Accuracy: 0.902
# Epoch: 8 Train Loss: 0.345 Train Accuracy: 0.897
# Epoch: 9 Train Loss: 0.318 Train Accuracy: 0.895
# Epoch: 10 Train Loss: 0.251 Train Accuracy: 0.922
# ############################### Teacher 96 Model Training #############################
# Epoch: 1 Train Loss: 1.694 Train Accuracy: 0.493
# Epoch: 2 Train Loss: 1.002 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.718 Train Accuracy: 0.807
# Epoch: 4 Train Loss: 0.520 Train Accuracy: 0.860
# Epoch: 5 Train Loss: 0.455 Train Accuracy: 0.870
# Epoch: 6 Train Loss: 0.399 Train Accuracy: 0.883
# Epoch: 7 Train Loss: 0.380 Train Accuracy: 0.885
# Epoch: 8 Train Loss: 0.343 Train Accuracy: 0.900
# Epoch: 9 Train Loss: 0.337 Train Accuracy: 0.892
# Epoch: 10 Train Loss: 0.276 Train Accuracy: 0.910
# ############################### Teacher 97 Model Training #############################
# Epoch: 1 Train Loss: 1.669 Train Accuracy: 0.477
# Epoch: 2 Train Loss: 1.016 Train Accuracy: 0.718
# Epoch: 3 Train Loss: 0.713 Train Accuracy: 0.798
# Epoch: 4 Train Loss: 0.526 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.420 Train Accuracy: 0.885
# Epoch: 6 Train Loss: 0.436 Train Accuracy: 0.875
# Epoch: 7 Train Loss: 0.336 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.337 Train Accuracy: 0.900
# Epoch: 9 Train Loss: 0.255 Train Accuracy: 0.927
# Epoch: 10 Train Loss: 0.257 Train Accuracy: 0.920
# ############################### Teacher 98 Model Training #############################
# Epoch: 1 Train Loss: 1.680 Train Accuracy: 0.462
# Epoch: 2 Train Loss: 1.036 Train Accuracy: 0.715
# Epoch: 3 Train Loss: 0.749 Train Accuracy: 0.788
# Epoch: 4 Train Loss: 0.670 Train Accuracy: 0.805
# Epoch: 5 Train Loss: 0.474 Train Accuracy: 0.882
# Epoch: 6 Train Loss: 0.435 Train Accuracy: 0.877
# Epoch: 7 Train Loss: 0.371 Train Accuracy: 0.898
# Epoch: 8 Train Loss: 0.391 Train Accuracy: 0.880
# Epoch: 9 Train Loss: 0.278 Train Accuracy: 0.923
# Epoch: 10 Train Loss: 0.321 Train Accuracy: 0.903
# ############################### Teacher 99 Model Training #############################
# Epoch: 1 Train Loss: 1.728 Train Accuracy: 0.447
# Epoch: 2 Train Loss: 1.061 Train Accuracy: 0.722
# Epoch: 3 Train Loss: 0.707 Train Accuracy: 0.813
# Epoch: 4 Train Loss: 0.540 Train Accuracy: 0.838
# Epoch: 5 Train Loss: 0.479 Train Accuracy: 0.857
# Epoch: 6 Train Loss: 0.456 Train Accuracy: 0.853
# Epoch: 7 Train Loss: 0.377 Train Accuracy: 0.893
# Epoch: 8 Train Loss: 0.246 Train Accuracy: 0.935
# Epoch: 9 Train Loss: 0.282 Train Accuracy: 0.912
# Epoch: 10 Train Loss: 0.254 Train Accuracy: 0.923
# ############################### Teacher 100 Model Training #############################
# Epoch: 1 Train Loss: 1.744 Train Accuracy: 0.425
# Epoch: 2 Train Loss: 1.032 Train Accuracy: 0.720
# Epoch: 3 Train Loss: 0.704 Train Accuracy: 0.797
# Epoch: 4 Train Loss: 0.524 Train Accuracy: 0.855
# Epoch: 5 Train Loss: 0.432 Train Accuracy: 0.892
# Epoch: 6 Train Loss: 0.374 Train Accuracy: 0.897
# Epoch: 7 Train Loss: 0.320 Train Accuracy: 0.900
# Epoch: 8 Train Loss: 0.290 Train Accuracy: 0.905
# Epoch: 9 Train Loss: 0.297 Train Accuracy: 0.913
# Epoch: 10 Train Loss: 0.227 Train Accuracy: 0.933

# %% [markdown]
# ## Teacher Models Predictions
#
# Now we have trained N teachers models and we can share those trained models for student training.
#
#
# We have assumed MNIST test dataset, as student dataset

# %%
# student dataset transforms 
test_transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize([.5],[.5])])
# load private student dataset
private_dataset = datasets.MNIST('./mnsit', train=False, transform=test_transform, download=True)

# mnist test dataset have 10000 examples
private_data_size = len(private_dataset)

# create dataloader for private train dataset
private_dataloader = torch.utils.data.DataLoader(private_dataset, batch_size=32)

# %%
def predict_model(model_checkpoint, dataloader):
  """ 
  Load a trained model and make predictions
  
  Parameters: 
    checkpoint_file (str): filename for trained model checkpoint
    dataloader (DataLoader): dataloader instance
          
  Returns: 
    preds_list (torch.Tensor): predictions for whole dataset
  
  """
  # create model 
  model = Network()
  # load model from checkpoint
  state_dict = torch.load(model_checkpoint)
  model.load_state_dict(state_dict)
  # send model to gpu
  model = model.to(DEVICE)
  # list for batch predictions
  preds_list = []
  # set model to eval mode
  model.eval()
  # no gradients calculation needed
  with torch.no_grad():
    # iterate over dataset
    for images, labels in dataloader:
      images = images.to(DEVICE)
      # calculate predictions ( log of predictions)
      preds = model.forward(images)
      # calculate top_class
      top_preds, top_classes = preds.topk(k=1, dim=1)
      # append batch top_classes tensor
      preds_list.append(top_classes.view(-1))
  # concat all batch predictions
  preds_list = torch.cat(preds_list).cpu()
  # return predictions
  return preds_list

# %%
# list of all teacher model predictions
teacher_preds = []
# predict for each teacher model
for teacher in range(num_teachers):
  teacher_preds.append(predict_model(f'checkpoint_teacher_{teacher+1}.pth', private_dataloader))
# stack all teacher predictions
teacher_preds = torch.stack(teacher_preds)
print(teacher_preds.shape)
# Out:
# torch.Size([100, 10000])

# %% [markdown]
# ## Aggregating Teacher Predictions
#
# We have N predictions for each datapoint from our private dataset. We can aggregate N predictions using max query on bin counts for different labels.
#
# Can we train a model on those aggregated labels directly ? Yes, we can, but for increasing differenital privacy and keeping within some privacy budget, we will convert our aggreagte query to dp query. In dp query, we will add some amount of gaussian noise.

# %%
# epsilon budget for one aggregate dp query
epsilon = 0.1 #@param {type:"number"}
# number of labels
num_classes = 10

# %% [markdown]
# we have assumed, student data is unlabelled. For analysis purpose we will use real labels.

# %%
# real targets, will not available for private dataset in real scenerio
real_targets = private_dataset.targets

# %% [markdown]
# ### Teacher Argmax Aggregation
#
# Aggregate N teacher predictions using max query on bin counts for different labels

# %%
# teacher aggregation result
teachers_argmax = list()
for image_i in range(private_data_size):
  # calculate bin count
  label_counts = torch.bincount(teacher_preds[:, image_i], minlength=num_classes)
  # take maximum bin count label
  argmax_label = torch.argmax(label_counts)
  teachers_argmax.append(argmax_label)
# convert array to 
teachers_argmax = torch.tensor(teachers_argmax)
# correct predictions
argmax_correct = torch.sum(real_targets == teachers_argmax)
print("Teachers argmax labels accuracy", argmax_correct.item()/private_data_size)
# Out:
# Teachers argmax labels accuracy 0.9207

# %% [markdown]
# ### Teacher Noisy Aggregation ( DP query)
#
# We use laplacian noise and beta will equal to **(sensitivity / epsilon )**.
#
# Sensitivity of argmax query will be one.

# %%
# dp query results
noisy_labels = list()
for image_i in range(private_data_size):
  # calculate bin count
  label_counts = torch.bincount(teacher_preds[:, image_i], minlength=num_classes)
  # calcuate beta for laplacian 
  beta = 1 / epsilon
  
  # add noise for each teacher predictions
  for i in range(len(label_counts)):
      label_counts[i] += int(np.random.laplace(0, beta, 1)[0])
  # calculate dp label
  noisy_label = torch.argmax(label_counts)
  noisy_labels.append(noisy_label)

noisy_labels = torch.tensor(noisy_labels)
# accuracy for noisy or dp query results
noisy_accuracy = torch.sum(real_targets == noisy_labels)

print("Noisy label accuracy", noisy_accuracy.item()/private_data_size)
# Out:
# Noisy label accuracy 0.9139

# %% [markdown]
# ## PATE Analysis
#
# **What is our epsilon budget, we have used ?** We will perform PATE analysis.

# %%
#from syft.frameworks.torch.differential_privacy import pate
from syft.frameworks.torch.dp import pate

# %%
# memory usage is getting pretty high with all predictions in PATE analysis,
# using subset of predictions ( subset of mnist test dataset)
# will help us understand importnace of private data size
num_student_train = 100 #@param {type:"integer"}
teacher_preds1 = teacher_preds[:, :num_student_train].to(DEVICE)
noisy_labels1 = noisy_labels[:num_student_train].to(DEVICE)
teachers_argmax1 = teachers_argmax[:num_student_train].to(DEVICE)
real_targets1 = real_targets[:num_student_train].to(DEVICE)

# %% [markdown]
# ### Noisy Labels PATE Analysis

# %%
# Data dependant and independant epsilon for noisy labels
data_dep_eps, data_ind_eps = pate.perform_analysis_torch(preds=teacher_preds1, indices=noisy_labels1,
                                                   noise_eps=epsilon, delta=1e-5, moments=10)
print(f"Data dependant epsilon {data_dep_eps.item()} data independent epsilon {data_ind_eps.item()}")
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data dependant epsilon 1.7345222234725952 data independent epsilon 11.756462097167969

# %% [markdown]
# ### Teacher Argmax PATE Analysis

# %%
# Data dependant and independant epsilon for argmax labels
data_dep_eps, data_ind_eps = pate.perform_analysis_torch(preds=teacher_preds1, indices=teachers_argmax1,
                                                   noise_eps=epsilon, delta=1e-5, moments=10)
print(f"Data dependant epsilon {data_dep_eps.item()} data independent epsilon {data_ind_eps.item()}")
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data dependant epsilon 1.7342612743377686 data independent epsilon 11.756462097167969

# %% [markdown]
# ### Real Labels PATE Analysis

# %%
# Data dependant and independant epsilon for argmax labels
data_dep_eps, data_ind_eps = pate.perform_analysis_torch(preds=teacher_preds1, indices=real_targets1,
                                                   noise_eps=epsilon, delta=1e-5, moments=10)
print(f"Data dependant epsilon {data_dep_eps.item()} data independent epsilon {data_ind_eps.item()}")
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data dependant epsilon 1.732116460800171 data independent epsilon 11.756462097167969

# %% [markdown]
# ## Student Model Training
#
# Differential privacy gaurantees that any amount of postprocessing can't increase epsilon value for given dataset, which means epsilon value will be less than or equal to PATE analysis values after training deep learning models.

# %%
# save real labels
private_real_labels = private_dataset.targets
# replace real labels with noisy labels in private dataset
private_dataset.targets = noisy_labels

# create training and testing subset
train_private_set = torch.utils.data.Subset(private_dataset, range(0, num_student_train))
test_private_set = torch.utils.data.Subset(private_dataset, range(num_student_train, len(private_dataset)))

# %%
# train student model with noisy labels
student_model = train_model(train_private_set, f'checkpoint_student.pth', num_epochs=20)
# Out:
# Epoch: 1 Train Loss: 2.124 Train Accuracy: 0.200
# Epoch: 2 Train Loss: 1.666 Train Accuracy: 0.540
# Epoch: 3 Train Loss: 1.299 Train Accuracy: 0.690
# Epoch: 4 Train Loss: 1.083 Train Accuracy: 0.740
# Epoch: 5 Train Loss: 1.121 Train Accuracy: 0.830
# Epoch: 6 Train Loss: 0.954 Train Accuracy: 0.800
# Epoch: 7 Train Loss: 0.793 Train Accuracy: 0.820
# Epoch: 8 Train Loss: 0.654 Train Accuracy: 0.890
# Epoch: 9 Train Loss: 0.599 Train Accuracy: 0.910
# Epoch: 10 Train Loss: 0.475 Train Accuracy: 0.920
# Epoch: 11 Train Loss: 0.764 Train Accuracy: 0.950
# Epoch: 12 Train Loss: 0.757 Train Accuracy: 0.920
# Epoch: 13 Train Loss: 0.385 Train Accuracy: 0.930
# Epoch: 14 Train Loss: 0.412 Train Accuracy: 0.900
# Epoch: 15 Train Loss: 0.414 Train Accuracy: 0.900
# Epoch: 16 Train Loss: 0.354 Train Accuracy: 0.930
# Epoch: 17 Train Loss: 0.422 Train Accuracy: 0.950
# Epoch: 18 Train Loss: 0.313 Train Accuracy: 0.950
# Epoch: 19 Train Loss: 0.327 Train Accuracy: 0.920
# Epoch: 20 Train Loss: 0.834 Train Accuracy: 0.930

# %%
# create test loader
private_testloader = torch.utils.data.DataLoader(test_private_set, batch_size=32)
# get test predictions 
test_preds = predict_model(f'checkpoint_student.pth', private_testloader)
# calculate test predictions 
correct = torch.sum(private_real_labels[num_student_train:] == test_preds)
# accuracy
print(f"student model test accuracy {correct.item()/(len(private_dataset)-num_student_train)}")
# Out:
# student model test accuracy 0.6737373737373737

# %% [markdown]
# ## Conclusion
#
# As you can see, we are able to train a quite good accuracy model.
#
# Try different values of epsilon and number of teachers, you should able to observe following :-
#
# 1.   More the numbers of teachers, less data dependent epsilon and more accuracy also
# 2.   By adding noise, we are able to reduce privacy budget hugely ( See difference between data dependent and Independent epsilon)
# 3.   Less the value of epsilon, more differntial privacy ( low data dependent and independent epsilon )
# 4.   Given enough examples, deep learning model will able to remove noise added during DP query without reducing differential privacy.
# 5.   More unlabelled student data, more accuracy
